# %% [markdown]
# # Scraping cases

# %% [markdown]
# ## Youbike Data

# %%
import requests
import json
response = requests.get('https://tcgbusfs.blob.core.windows.net/blobyoubike/YouBikeTP.gz')
print(response)
print(response.status_code)
print(response.headers)
print(type(response)) # <class 'requests.models.Response'>
print(type(response.text)) # <class 'str'>
# Out:
# <Response [200]>
# 200
# {'Content-Length': '30479', 'Content-Type': 'application/octet-stream', 'Content-Encoding': 'gzip', 'Content-MD5': 'SNpHQdX7IGuibCTi/yq7uQ==', 'Last-Modified': 'Sun, 18 Sep 2022 14:45:59 GMT', 'ETag': '0x8DA9984806FB0FF', 'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0', 'x-ms-request-id': '51abd6f4-e01e-0090-2d6d-cb6f9f000000', 'x-ms-version': '2009-09-19', 'x-ms-lease-status': 'unlocked', 'x-ms-blob-type': 'BlockBlob', 'Access-Control-Allow-Origin': '*', 'Date': 'Sun, 18 Sep 2022 14:46:22 GMT'}
# <class 'requests.models.Response'>
# <class 'str'>

# %% [markdown]
# ## Taipei Bus

# %%
import requests
import json
url = "https://pda.5284.gov.taipei/MQS/RouteDyna?routeid=11763&nocache=1633009377839"
response = requests.get(url)
route = json.loads(response.text)
print(type(route))
# Out:
# <class 'dict'>

# %% [markdown]
# ## Cnyes

# %%
import requests
import json
url_cnyes = "https://news.cnyes.com/api/v3/news/category/headline?startAt=1588262400&endAt=1589212799&limit=30"
res = requests.get(url_cnyes).json()
print(type(res))
# Out:
# <class 'dict'>

# %% [markdown]
# ## 104.com

# %%
import pandas as pd
url_104 = 'https://www.104.com.tw/jobs/search/list?ro=0&kwop=7&keyword=data%20scientist&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page=2&mode=s&jobsource=2018indexpoc'
headers = {'referer': 'https://www.104.com.tw/'}
raw = requests.get(url_104, headers=headers).json()
print(type(raw))
# Out:
# <class 'dict'>

# %%
print(raw.keys())
print(type(raw['data']))
print(raw['data'].keys())
print(type(raw['data']['list']))
print(type(raw['data']['list'][0]))
pd.DataFrame(raw['data']['list'])
# Out:
# dict_keys(['status', 'action', 'data', 'statusMsg', 'errorMsg'])
# <class 'dict'>
# dict_keys(['query', 'filterDesc', 'queryDesc', 'list', 'count', 'pageNo', 'totalPage', 'totalCount'])
# <class 'list'>
# <class 'dict'>
#    jobType     jobNo                                            jobName  \
# 0        0  10856947                               數據科學家 Data Scientist
# 1        2  10760108              資料科學家 Data Scientist-數據科技(數數發中心, DDT)
# 2        2  13008885  資料科學家 Data Scientist R&amp;D - 資料科學研發科 (數數發中心,...
# 3        0   7618755                       Data Scientist(資料科學家/AI 工程師)
# 4        2  12583605  數據科學家(統計) Data Scientist(Statistician) (Data S...
# 5        0  12844505                     Data Scientist資料科學家(遠端工作)-T05P
# 6        0  12504693  Data Scientist - Analytics (Product) / 資料科學家 -...
# 7        2  10917374                       AI人工智能資料科學家 (Data Scientist)
# 8        2  12289370                                    Data scientist
# 9        0  13028742  【111年產博後計畫】東元電機股份有限公司-AI人工智能資料科學家(Data Scienti...
# 10       0  10589685             Data Scientist 資料科學家_數據分析師 | CBU_21_13
# 11       2  12602344                         [AD RD] Sr. Data Scientist
# 12       0  12547187  【DNA, Data &amp; AI】Data Scientist &amp; AI En...
# 13       2  12872678                      Gogoro Network_Data Scientist
# 14       2  10507560  【採線上面談】Senior Data Scientist 資深資料科學家 - Annual ...
# 15       2  12732481                                     Data Scientist
# 16       2  12657040                    [Data Sci] Chief Data Scientist
# 17       2  12188993                          Full Stack Data Scientist
# 18       0  12716606                           Data Scientist數據工程師-T03P
# 19       2  12689367                       Data Scientist / 資料科學家_11060
#
#                                        jobNameSnippet jobRole jobRo  \
# 0   <em class='b-txt--highlight'>數據科學家</em> <em cl...       1     1
# 1   <em class='b-txt--highlight'>資料科學家</em> <em cl...       1     1
# 2   <em class='b-txt--highlight'>資料科學家</em> <em cl...       1     1
# 3   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 4   <em class='b-txt--highlight'>數據科學家</em>(統計) <e...       1     1
# 5   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 6   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 7   AI人工智能<em class='b-txt--highlight'>資料科學家</em> ...       1     1
# 8   <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 9   【111年產博後計畫】東元電機股份有限公司-AI人工智能<em class='b-txt--...       1     1
# 10  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 11  [AD RD] Sr. <em class='b-txt--highlight'>Data<...       1     1
# 12  【DNA, <em class='b-txt--highlight'>Data</em> &...       1     1
# 13  Gogoro Network_<em class='b-txt--highlight'>Da...       1     1
# 14  【採線上面談】Senior <em class='b-txt--highlight'>Dat...       1     1
# 15  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 16  <em class='b-txt--highlight'>[Data</em> Sci] C...       1     1
# 17  Full Stack <em class='b-txt--highlight'>Data</...       1     1
# 18  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
# 19  <em class='b-txt--highlight'>Data</em> <em cla...       1     1
#
#      jobAddrNo jobAddrNoDesc                    jobAddress  \
# 0   6001001007        台北市信義區                    松仁路100號10樓
# 1   6001001007        台北市信義區                         松仁路7號
# 2   6001001007        台北市信義區                         松仁路7號
# 3   6001016009        高雄市楠梓區                           研發路
# 4   6001002016        新北市土城區
# 5   6001001003        台北市中山區
# 6   6001001002        台北市大同區                           承德路
# 7   6001001011        台北市南港區                    三重路19-9號5樓
# 8   6001002004        新北市汐止區                   新台五路1段99號5樓
# 9   6001001011        台北市南港區
# 10  6001002020        新北市三重區                三和路四段111之32號7樓
# 11  6001001004        台北市松山區                    復興北路337號7樓
# 12  6001002020        新北市三重區   新北市三重區重新路四段12號 (近捷運菜寮站及三重站）
# 13  6001001004        台北市松山區
# 14  6001001011        台北市南港區  台北市南港區園區街3之1號11樓之1（南港軟體園區G棟）
# 15  6001006002        新竹縣竹北市                      台元街22號1樓
# 16  6001001004        台北市松山區                    復興北路337號7樓
# 17  6001008014        台中市后里區                     三豐路四段369號
# 18  6001006001           新竹市
# 19  6001001009        台北市北投區                        立功街96號
#
#                                           description  ...  \
# 0   Isobar作為數位轉型與數位創新的領導品牌，領先市場佈局打造專業的CR-Marketing...  ...
# 1   [主要任務]\n1. 機器學習、深度學習或統計分析模型的實作開發，包含數據資料清洗、特徵工程...  ...
# 2   **【工作內容】**\n\n隸屬於國泰金控下的資料科學實驗室 Cathay [[[Data]...  ...
# 3   1. 洞察公司營銷/工廠運維的數據，並應用數據挖掘、機器/深度學習、最佳化等等技術，優化產品...  ...
# 4    technologies that enhance the [[[data]]] valu...  ...
# 5   •\tDesign, develop, and launch extremely effic...  ...
# 6    Analyst Team as a [[[Data]]] [[[Scientist]]]....  ...
# 7   1.建立端對端(End-to-End) AI分析流程「數據收集-數據處理-特徵工程-模型訓練...  ...
# 8   We are looking for a [[[Data]]] [[[Scientist]]...  ...
# 9   【職缺】\nAI人工智能資料科學家([[[Data]]] [[[Scientist]]])\...  ...
# 10  分群、推薦、迴歸預測等演算法理論基礎，並有實作經驗\r\n2. 熟悉程式與分析應用，如 Py...  ...
# 11   numerical techniques, algorithms and ML model...  ...
# 12  Pytorch等\n4. 熟悉大數據生態系(Big [[[Data]]] Ecosystem...  ...
# 13  Position Impact:\nAs a [[[Data]]] [[[Scientist...  ...
# 14  【What a [[[Data]]] [[[Scientist]]] does in Tit...  ...
# 15   teams with creation of advance [[[data]]] ana...  ...
# 16  [About The Job]\n* Lead the ML Team to build t...  ...
# 17  As a full-stack [[[data]]] [[[scientist]]] at ...  ...
# 18   the expected outcome\n•\tIdentify and select ...  ...
# 19   learning / deep learning papers, and have the...  ...
#
#                            tags        landmark  \
# 0                      [員工120人]     距捷運象山站290公尺
# 1                [上市上櫃, 員工400人]    距捷運市政府站430公尺
# 2                [上市上櫃, 員工400人]    距捷運市政府站430公尺
# 3               [上市上櫃, 員工1000人]
# 4                        [上市上櫃]
# 5          [外商公司, 員工200人, 遠端工作]
# 6                      [員工180人]
# 7               [上市上櫃, 員工2500人]  距捷運南港展覽館站270公尺
# 8                            []
# 9                       [員工40人]
# 10                     [員工300人]   距捷運三和國中站110公尺
# 11               [外商公司, 員工150人]    距捷運中山國中站70公尺
# 12                     [員工110人]     距捷運菜寮站440公尺
# 13                    [員工2300人]
# 14               [外商公司, 員工300人]  距捷運南港展覽館站400公尺
# 15              [外商公司, 員工1000人]
# 16               [外商公司, 員工150人]    距捷運中山國中站70公尺
# 17  [上市上櫃, 外商公司, 員工9000人, 遠端工作]
# 18               [外商公司, 員工200人]
# 19                    [員工6000人]     距捷運關渡站410公尺
#
#                                                  link           jobsource  \
# 0   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 1   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 2   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 3   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 4   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 5   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 6   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 7   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 8   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 9   {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 10  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 11  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 12  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 13  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 14  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 15  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 16  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 17  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 18  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
# 19  {'applyAnalyze': '//www.104.com.tw/jobs/apply/...  jolist_b_relevance
#
#                                            jobNameRaw  \
# 0                                數據科學家 Data Scientist
# 1               資料科學家 Data Scientist-數據科技(數數發中心, DDT)
# 2     資料科學家 Data Scientist R&D - 資料科學研發科 (數數發中心, DDT)
# 3                        Data Scientist(資料科學家/AI 工程師)
# 4   數據科學家(統計) Data Scientist(Statistician) (Data S...
# 5                      Data Scientist資料科學家(遠端工作)-T05P
# 6   Data Scientist - Analytics (Product) / 資料科學家 -...
# 7                        AI人工智能資料科學家 (Data Scientist)
# 8                                     Data scientist
# 9   【111年產博後計畫】東元電機股份有限公司-AI人工智能資料科學家(Data Scienti...
# 10             Data Scientist 資料科學家_數據分析師 | CBU_21_13
# 11                         [AD RD] Sr. Data Scientist
# 12  【DNA, Data & AI】Data Scientist & AI Engineer_資...
# 13                      Gogoro Network_Data Scientist
# 14  【採線上面談】Senior Data Scientist 資深資料科學家 - Annual ...
# 15                                     Data Scientist
# 16                    [Data Sci] Chief Data Scientist
# 17                          Full Stack Data Scientist
# 18                           Data Scientist數據工程師-T03P
# 19                       Data Scientist / 資料科學家_11060
#
#                                           custNameRaw          lon  \
# 0                                           安索帕股份有限公司  121.5678798
# 1                                   國泰金控_國泰金融控股股份有限公司  121.5691563
# 2                                   國泰金控_國泰金融控股股份有限公司  121.5691692
# 3                                       李長榮化學工業股份有限公司  120.3001296
# 4                                        鴻海精密工業股份有限公司   121.438034
# 5   Tata Consultancy Services Limited Taiwan Branc...  121.5427093
# 6                           Pinkoi_香港商果翼科技股份有限公司台灣分公司  121.5169834
# 7                                          東元電機股份有限公司  121.6137637
# 8                                            傑希生技有限公司  121.6484523
# 9                                      國立成功大學_產學創新總中心  121.6111949
# 10                                      伊雲谷數位科技股份有限公司  121.4856118
# 11                                        威朋大數據股份有限公司  121.5446271
# 12                                         雲馥數位股份有限公司  121.4887337
# 13                   Gogoro Taiwan Limited_睿能創意股份有限公司  121.5638621
# 14                                新加坡商鈦坦科技股份有限公司台灣分公司  121.6123229
# 15                         美商科磊股份有限公司台灣分公司_KLA Taiwan   121.012749
# 16                                        威朋大數據股份有限公司  121.5446271
# 17  台灣美光(台灣美光晶圓科技股份有限公司/台灣美光記憶體股份有限公司/美商美光亞太科技股份有限...  120.7240916
# 18  Tata Consultancy Services Limited Taiwan Branc...  120.9674798
# 19                                  和碩集團_和碩聯合科技股份有限公司  121.4712373
#
#            lat remoteWorkType                          major
# 0   25.0344547              0        [統計學相關, 一般商業學類, 資訊管理相關]
# 1   25.0382555              0                             []
# 2   25.0382529              0  [數理統計相關, 應用數學相關, 數學及電算機科學學科類]
# 3   22.7136179              0   [數學及電算機科學學科類, 統計學相關, 資訊工程相關]
# 4    24.968371              0                       [數理統計相關]
# 5   25.0792018              2       [資訊工程相關, 數理統計相關, 資訊管理相關]
# 6   25.0504544              0                             []
# 7     25.05764              0   [數學及電算機科學學科類, 資訊工程相關, 工程學科類]
# 8   25.0620251              0                             []
# 9   25.0312347              0           [數學及電算機科學學科類, 工程學科類]
# 10  25.0774577              0                             []
# 11   25.060227              0    [數學及電算機科學學科類, 物理學相關, 統計學相關]
# 12  25.0576383              0       [數理統計相關, 資訊工程相關, 應用數學相關]
# 13  25.0541591              0                             []
# 14  25.0574363              0       [資訊管理相關, 資訊工程相關, 數理統計相關]
# 15   24.840712              0  [數學及電算機科學學科類, 數理統計相關, 資訊工程相關]
# 16   25.060227              0           [數學及電算機科學學科類, 統計學相關]
# 17  24.3181102              2     [資訊工程相關, 資訊管理相關, 電機電子工程相關]
# 18  24.8138287              0       [資訊工程相關, 數理統計相關, 資訊管理相關]
# 19   25.124796              0                [資訊工程相關, 統計學相關]
#
# [20 rows x 40 columns]

# %% [markdown]
# ## Taipei Bus
