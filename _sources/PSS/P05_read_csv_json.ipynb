# %% [markdown]
# # P05 READ Files
#
# - Read [Slide](https://docs.google.com/presentation/d/1ZQoBdfjIsd-RdXEby3RmFfotBHZXR0bzKzhaZThkfJU/edit?usp=sharing) to know what is CSV and JSON
# - Read CSV (Metdho 1, 2, 3)
# - Read JSON
# - Load CSV and JSON by pandas
# - Eseential functions in Pandas
# - Convert data structures

# %% [markdown]
# ## Get files
#
# 資料來源：政府開放資料[違規藥品廣告資料集](https://data.gov.tw/dataset/14196)

# %% [markdown]
# ### File path
#
# - 若已經把ipynb下載回本機端，就只需要把相對位置作為資料路徑即可。
# - 如果是都在colab上執行，就要先在程式中mount google drive，並把位置指到相對應的路徑。

# %%
# !wget

# %%
#Mount google drive as data
from google.colab import drive
drive.mount('/content/drive')

# data path using google colab
gdrive_path = "/content/drive/My Drive/Colab Notebooks/PSS1092/data/14196_drug_adv.csv"

# %%
# local PC
relative_path = "../data/drug_156_2.csv"   

# Assign gdrive_path as my fin_path(file_in_path)
# fin_path = gdrive_path # if run on google drive
fin_path = relative_path

# %% [markdown]
# ### Read files
#
# 當規劃要讀進一個CSV檔時，我可能有三種做法：
# 1. 全部靠自己逐行讀，用`readlines()`來判斷換行符號，將所有資料依照換行符號切割為list內的Element，再將每個Elements遇到逗號進行切割。
# 2. 利用`csv.reader()`函式幫我把文字資料轉換成python物件
# 3. 利用pandas的函式讀檔

# %% [markdown]
# ### CSV檔案內容
# 當我用`f.read()`讀取純文字檔案內的內容時，整個內容會被轉為單一string。由於我加了Slicing `f.read()[:400]`來取出前400個字，剛好可以看見第一列的詮釋資料、第一二三筆資料，但到了第三筆資料的一半，便超過400個字。

# %%
with open(fin_path, "r", encoding="utf-8-sig") as f:
    print(f)
    print(type(f))
# Out:
# <_io.TextIOWrapper name='../data/drug_156_2.csv' mode='r' encoding='utf-8-sig'>
# <class '_io.TextIOWrapper'>

# %%
with open(fin_path, "r", encoding="utf-8-sig") as f:
    print(f.read()[:400])
# Out:
# 違規產品名稱,違規廠商名稱或負責人,處分機關,處分日期,處分法條,違規情節,刊播日期,刊播媒體類別,刊播媒體,查處情形
# "《現貨》日本熱銷 超人氣SS製藥 痘痘乳膏","Y7868533113/鍾青砡","","08 15 2017 12:00AM","","無照藥商","02 3 2017 12:00AM","網路","Yahoo！奇摩拍賣","相關案件已處分"
# "《現貨》大正漢方腸胃藥 60錠","Y9159169900/鍾青砡","","08 15 2017 12:00AM","","無照藥商","02 3 2017 12:00AM","網路","Yahoo！奇摩拍賣","相關案件已處分"
# "《現貨》日本熱銷 超人氣SS製藥 痘痘乳膏","Y9159169900/鍾青砡","","08 15 2017 12:00AM","","無照藥商","02 3 2017 12:00AM","網

# %% [markdown]
# ### M.1 Read CSV by lines
#
# 前面說到，CSV檔的每一列都有一個`\n`做換行，所以，我要讀取CSV就可以用`f.readlines()`讀進每一列的資料，該函式會遇到`\n`即切開為一行，切開後的資料就存進一個外層List中。之後，我可以針對切開的每一列資料（例如底下的`line`），遇到逗號就斷開`line.split(",")`，每一列就會變成一個List。所以最後會產生一個兩層的List。
#
# * `.read()`是讀取整個檔案變成一個字串，因此，必須在後面跟著用`split()`函式，讓這個大字串遇到`\n`就會切成分行的小字串。
#
# * `.readllines()`是上面兩個步驟的簡短版，讀檔過程遇到`\n`會自動把大字串切為數個小字串並放到List中。

# %%
all_list = []
with open(fin_path, "r", encoding="utf-8-sig") as f:
#     for line in f.readlines():
    for line in f.read().split("\n"):
        row = line.split(",")
        all_list.append(row)

# %%
# Explore the data
print(type(all_list))
print(len(all_list))
print(all_list[:3])
# Out:
# <class 'list'>
# 2973
# [['違規產品名稱', '違規廠商名稱或負責人', '處分機關', '處分日期', '處分法條', '違規情節', '刊播日期', '刊播媒體類別', '刊播媒體', '查處情形'], ['"維他肝"', '"豐怡生化科技股份有限公司/朱O"', '""', '"03 31 2022 12:00AM"', '""', '"廣告內容誇大不實"', '"02 2 2022 12:00AM"', '"廣播電台"', '"噶瑪蘭廣播電台股份有限公司"', '""'], ['"現貨澳洲Swisse ULTIBOOST維他命D片calcium vitamin VITAMIN D400粒 補鈣 骨頭"', '"張O雯/張O雯"', '""', '"01 21 2022 12:00AM"', '""', '"廣告違規"', '"11 30 2021 12:00AM"', '"網路"', '"蝦皮購物"', '"輔導結案"']]

# %%
# print the first 5 lists by for-loop
for li in all_list[:5]:
    print(li)

# print the length of data (the length of the outer list)
print(len(all_list))


# print element by index with two dimensions
print(all_list[1][-2])
# Out:
# ['違規產品名稱', '違規廠商名稱或負責人', '處分機關', '處分日期', '處分法條', '違規情節', '刊播日期', '刊播媒體類別', '刊播媒體', '查處情形']
# ['"維他肝"', '"豐怡生化科技股份有限公司/朱O"', '""', '"03 31 2022 12:00AM"', '""', '"廣告內容誇大不實"', '"02 2 2022 12:00AM"', '"廣播電台"', '"噶瑪蘭廣播電台股份有限公司"', '""']
# ['"現貨澳洲Swisse ULTIBOOST維他命D片calcium vitamin VITAMIN D400粒 補鈣 骨頭"', '"張O雯/張O雯"', '""', '"01 21 2022 12:00AM"', '""', '"廣告違規"', '"11 30 2021 12:00AM"', '"網路"', '"蝦皮購物"', '"輔導結案"']
# ['"✈日本 代購 參天製藥 處方簽點眼液"', '"蘇O涵/蘇O涵"', '""', '"01 25 2022 12:00AM"', '""', '"無照藥商"', '"08 27 2021 12:00AM"', '"網路"', '"蝦皮購物"', '""']
# ['"✈日本 代購 TSUMURA 中將湯 24天包裝"', '"蘇O涵/蘇O涵"', '""', '"01 25 2022 12:00AM"', '""', '"無照藥商"', '"08 27 2021 12:00AM"', '"網路"', '"蝦皮購物"', '"輔導結案"']
# 2973
# "噶瑪蘭廣播電台股份有限公司"

# %% [markdown]
# ### M.2 Read by csv.reader()

# %% [markdown]
# `csv_read()`並非預載於python runtime environment的基本函式，因此要import csv library，才可以使用該library中的`csv_read()`

# %%
import csv
with open(fin_path, "r", encoding="utf-8-sig") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    data_list  = list(csv_reader)

# %%
# Exploring data content, the first and the second elements
print(data_list[0])
print(data_list[1])

print(data_list[1][-2])
print(len(data_list))

# for row in data_list: # never do this if you are not sure that the number of lines
#     print(row)
# Out:
# ['違規產品名稱', '違規廠商名稱或負責人', '處分機關', '處分日期', '處分法條', '違規情節', '刊播日期', '刊播媒體類別', '刊播媒體', '查處情形']
# ['維他肝', '豐怡生化科技股份有限公司/朱O', '', '03 31 2022 12:00AM', '', '廣告內容誇大不實', '02 2 2022 12:00AM', '廣播電台', '噶瑪蘭廣播電台股份有限公司', '']
# 噶瑪蘭廣播電台股份有限公司
# 2973

# %% [markdown]
# ### M.3 Read by pandas data.frame

# %%
import pandas as pd
df = pd.read_csv(fin_path, on_bad_lines='skip')

# %%
df
# Out:
#                                                  違規產品名稱       違規廠商名稱或負責人 處分機關  \
# 0                                                   維他肝  豐怡生化科技股份有限公司/朱O  NaN
# 1     現貨澳洲Swisse ULTIBOOST維他命D片calcium vitamin VITAM...          張O雯/張O雯  NaN
# 2                                    ✈日本 代購 參天製藥 處方簽點眼液          蘇O涵/蘇O涵  NaN
# 3                              ✈日本 代購 TSUMURA 中將湯 24天包裝          蘇O涵/蘇O涵  NaN
# 4                                 _Salty.shop 日本代購 樂敦小花          曾O嫺/曾O嫺  NaN
# ...                                                 ...              ...  ...
# 2967                                  *健人館* 千鶴薄荷棒11g*2個       新東海藥局/ O聰敏  NaN
# 2968                 （現貨）GO LIVER DETOX 高之源 護肝排毒膠囊 120粒          連O毅/連O毅  NaN
# 2969                                        日本帶回樂敦小花新鮮貨          張O萍/張O萍  NaN
# 2970  全新 洗眼杯 可平信 洗眼 小林製藥 小花 ROHTO Lycee 可搭配生理食鹽水 空汙 ...            盧O/盧O  NaN
# 2971                        0.9%生理食鹽水 20ml 預購最低價 每人限購2盒          張O軒/張O軒  NaN
#
#                     處分日期     處分法條       違規情節                刊播日期 刊播媒體類別  \
# 0     03 31 2022 12:00AM      NaN   廣告內容誇大不實   02 2 2022 12:00AM   廣播電台
# 1     01 21 2022 12:00AM      NaN       廣告違規  11 30 2021 12:00AM     網路
# 2     01 25 2022 12:00AM      NaN       無照藥商  08 27 2021 12:00AM     網路
# 3     01 25 2022 12:00AM      NaN       無照藥商  08 27 2021 12:00AM     網路
# 4     02 17 2022 12:00AM  藥事法第27條       無照藥商   12 6 2021 12:00AM     網路
# ...                  ...      ...        ...                 ...    ...
# 2967                 NaN  藥事法第27條  標示內容與規定不符   05 6 2020 12:00AM     網路
# 2968  06 30 2020 12:00AM  藥事法第27條       無照藥商   02 5 2020 12:00AM     網路
# 2969  06 23 2020 12:00AM      NaN   難以判定產品屬性  03 10 2020 12:00AM     網路
# 2970   09 4 2020 12:00AM      NaN       無照藥商  03 10 2020 12:00AM     網路
# 2971  06 11 2020 12:00AM      NaN       無照藥商  03 31 2020 12:00AM     網路
#
#                刊播媒體  查處情形
# 0     噶瑪蘭廣播電台股份有限公司   NaN
# 1              蝦皮購物  輔導結案
# 2              蝦皮購物   NaN
# 3              蝦皮購物  輔導結案
# 4              蝦皮購物  處分結案
# ...             ...   ...
# 2967            NaN  處分結案
# 2968           蝦皮購物  處分結案
# 2969           蝦皮購物  輔導結案
# 2970           蝦皮購物  輔導結案
# 2971           蝦皮購物   NaN
#
# [2972 rows x 10 columns]

# %% [markdown]
# #### Read url directly by pandas
# 1. 至https://data.taipei/ 搜尋「結婚」可找到「臺北市婚姻概況按月別」後，對「下載資料」按右鍵複製連結即得https://data.taipei/api/getDatasetInfo/downloadResource?id=bc83f1a0-2192-4e06-acc2-4d2a0bc9121b&rid=d4ce96ce-a463-40dc-95b2-0c88d81a5427
#
#
# 2. (無法直接讀取URL，只能用下載的) Find an interesting dataset on https://data.gov.tw/ (e.g.) 結婚對數按婚姻類型、性別及年齡分(按登記) https://data.gov.tw/dataset/130547 . Click "檢視資料" to obtain data link https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=50E1F8E9-3A75-45A7-A50D-306CC625A700

# %%
import pandas as pd
url = 'https://data.taipei/api/getDatasetInfo/downloadResource?id=bc83f1a0-2192-4e06-acc2-4d2a0bc9121b&rid=d4ce96ce-a463-40dc-95b2-0c88d81a5427'
df = pd.read_csv(url, on_bad_lines="skip", encoding='big5')
df
# Out:
#         年月別  結婚對數[對] 結婚對數中相同性別對數[對] 結婚對數中對象為大陸港澳配偶對數[對]  結婚對數中對象為其他外籍配偶對數[對]  \
# 0     87年1月     2158              -                   -                   75
# 1     87年2月     1926              -                   -                   87
# 2     87年3月     1755              -                   -                  106
# 3     87年4月     1402              -                   -                   82
# 4     87年5月     1348              -                   -                   93
# ..      ...      ...            ...                 ...                  ...
# 290  111年3月     1131             17                  48                   82
# 291  111年4月      695             20                  40                   61
# 292  111年5月     1478             25                  29                   74
# 293  111年6月     1003             15                  39                   82
# 294  111年7月      999             26                  50                   85
#
#      結婚對數中配偶為大陸港澳及其他外籍人士之對數比率[%]  結婚人數中大陸港澳及其他外籍配偶之人數比率[%]  粗結婚率/月[千分比]  \
# 0                           3.48                      1.74         0.83
# 1                           4.52                      2.26         0.74
# 2                           6.04                      3.02         0.67
# 3                           5.85                      2.92         0.54
# 4                           6.90                      3.45         0.52
# ..                           ...                       ...          ...
# 290                        11.49                      5.75         0.45
# 291                        14.53                      7.27         0.28
# 292                         6.97                      3.48         0.60
# 293                        12.06                      6.03         0.41
# 294                        13.51                      6.76         0.41
#
#      粗結婚率/折合年率[千分比]  離婚對數[對] 離婚對數中相同性別對數[對] 離婚對數中對象為大陸港澳配偶對數[對]  \
# 0              9.78      344              -                   -
# 1              9.65      423              -                   -
# 2              7.94      479              -                   -
# 3              6.54      487              -                   -
# 4              6.08      470              -                   -
# ..              ...      ...            ...                 ...
# 290            5.33      449              2                  37
# 291            3.40      350              3                  27
# 292            7.03      327              4                  25
# 293            4.95      378              2                  29
# 294            4.77      386              3                  32
#
#      離婚對數中對象為其他外籍配偶對數[對]  離婚對數中配偶為大陸港澳及其他外籍人士之對數比率[%]  \
# 0                     11                         3.20
# 1                     15                         3.55
# 2                     12                         2.51
# 3                      8                         1.64
# 4                     16                         3.40
# ..                   ...                          ...
# 290                   33                        15.59
# 291                   20                        13.43
# 292                   24                        14.98
# 293                   27                        14.81
# 294                   26                        15.03
#
#      離婚人數中大陸港澳及其他外籍配偶之人數比率[%]  粗離婚率/月[千分比]  粗離婚率/折合年率[千分比]
# 0                        1.60         0.13            1.56
# 1                        1.77         0.16            2.12
# 2                        1.25         0.18            2.17
# 3                        0.82         0.19            2.27
# 4                        1.70         0.18            2.12
# ..                        ...          ...             ...
# 290                      7.80         0.18            2.12
# 291                      6.71         0.14            1.71
# 292                      7.49         0.13            1.56
# 293                      7.41         0.15            1.86
# 294                      7.51         0.16            1.84
#
# [295 rows x 17 columns]

# %% [markdown]
# ## Read JSON

# %% [markdown]
# ### Dump and load JSON
#
# 通常把資料寫到檔案中稱為dump out（或者save、write視程式語言的函式而不同），而把資料從檔案中讀成程式語言所能處理的結構則稱為load（或read）。無論是讀入資料或寫出資料，都要先開啟檔案（如`open('sample.json', 'w')`）。檔案開啟後，才可以將資料寫入。完整的寫法如下：
# ```
# json.dump(sample_data, open('sample.json', 'w'))
# ```
# 一個更常見的寫法如下，其將開檔後的結果指到一個變項`fout`，藉此把資料dump到檔案中。
# ```
# with open('sample.json', 'w') as fout:
#     json.dump(sample_data, fout)
# ```
# 讀取JSON則分讀取字串和直接讀取檔案兩種：
# * `json.loads(str)`讀取字串：例如像讀取ubike的線上資料，就是先把抓回來的資料轉文字後當成字串讀取入json。
# * `json.load(f)`直接讀取檔案：例如適才把一個list of dictionary存成json後，可以用`json.load(f)`讀成python的list of dictionary

# %%
## dump out
import json
sample_data = [{"site":"基隆","AQI":38,"PM25":8},\
               {"site":"新店","AQI":40,"PM25":9},\
               {"site":"苗栗","AQI":76,"PM25":11}]
json.dump(sample_data, open('sample.json', 'w'))

# %%
## load back
with open("sample.json", "r") as f:
    new_data = json.load(f)
new_data
# Out:
# [{'site': '基隆', 'AQI': 38, 'PM25': 8},
#  {'site': '新店', 'AQI': 40, 'PM25': 9},
#  {'site': '苗栗', 'AQI': 76, 'PM25': 11}]

# %% [markdown]
# ### Example: Loading json: ubike
#
# 這個例子載入了台北市ubike的即時資料，該資料以JSON格式儲存，但他並非List of dict(s)的型態，而是Dict of dict(s)的型態，在最外面亦多一層Dictionary包裹著資料和回傳是否傳輸成功的確認碼。因此，和一般的例子比較起來，這個例子必須要找到資料的節點，在解出為Python的物件時，也要考慮如何處理資料中兩層的Dictionary。

# %% [markdown]
# #### Step 1. requests to get data from internet
# 在以下的程式碼中，我用`requests`這個套件發出一個`get()`要求，然後我嘗試列印出一些該要求的回傳資料，以確認我成功地獲得我要求的資料。

# %%
import requests
import json
response = requests.get('https://tcgbusfs.blob.core.windows.net/blobyoubike/YouBikeTP.gz')
print(response)
print(response.status_code)
print(response.headers)
print(type(response)) # <class 'requests.models.Response'>
print(type(response.text)) # <class 'str'>
# Out:
# <Response [200]>
# 200
# {'Content-Length': '30436', 'Content-Type': 'application/octet-stream', 'Content-Encoding': 'gzip', 'Content-MD5': 'Uv/nA/2k5aabbAoHSF2/4g==', 'Last-Modified': 'Mon, 19 Sep 2022 06:09:59 GMT', 'ETag': '0x8DA9A05954224B2', 'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0', 'x-ms-request-id': '42acdc17-601e-002b-09ee-cb8e6b000000', 'x-ms-version': '2009-09-19', 'x-ms-lease-status': 'unlocked', 'x-ms-blob-type': 'BlockBlob', 'Access-Control-Allow-Origin': '*', 'Date': 'Mon, 19 Sep 2022 06:10:19 GMT'}
# <class 'requests.models.Response'>
# <class 'str'>

# %% [markdown]
# 把前500個字元印出來可以看到這裡面只有大括號，而且在資料（`retVal`所對應到的那個大括號）外面還有一層，也就是`retCode`和`retVal`所在的那一層大括號。

# %%
response.text[:500]
# Out:
# '{"retCode":1,"retVal":{"0001":{"sno": "0001", "sna": "捷運市政府站(3號出口)", "tot": "88", "sbi": "6", "sarea": "信義區", "mday": "20220919140825", "lat": "25.0408578889", "lng": "121.567904444", "ar": "忠孝東路/松仁路(東南側)", "sareaen": "Xinyi Dist.", "snaen": "MRT Taipei City Hall Stataion(Exit 3)-2", "aren": "The S.W. side of Road Zhongxiao East Road & Road Chung Yan.", "bemp": "77", "act": "1"},"0002":{"sno": "0002", "sna": "捷運國父紀念館站(2號出口)", "tot": "16", "sbi": "4", "sarea": "大安區", "mday": "20220919140833", "la'

# %% [markdown]
# #### Step 2. Convert json text to python objects

# %%
json_obj = json.loads(response.text)
print(type(json_obj))
print(type(json_obj["retVal"]))
print(type(json_obj["retCode"]))
print(len(json_obj["retVal"]))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'int'>
# 371

# %% [markdown]
# ### Load youbike json by pandas
#
# 如果要載入的JSON資料檔是表述為**a List of dict**，那麼pandas套件有函式可以將JSON字串轉為data frame。可以從以下的stackoverflow網站找到類似的函式。但如果資料並非典型List of dict的型態，那麼被解出來的資料常不會是所預期的List of dictionary的型態。不過，總之JSON解析後所轉成的Python物件必然是
# https://stackoverflow.com/questions/20638006/convert-list-of-dictionaries-to-dataframe

# %%
import pandas as pd
# df = pd.DataFrame(json_obj)
# df = pd.DataFrame(json_obj['retVal'])
df = pd.DataFrame.from_dict(json_obj['retVal'], orient='index')
df.head()
# Out:
#        sno             sna tot sbi sarea            mday            lat  \
# 0001  0001    捷運市政府站(3號出口)  88   6   信義區  20220919140825  25.0408578889
# 0002  0002  捷運國父紀念館站(2號出口)  16   4   大安區  20220919140833      25.041254
# 0004  0004            市民廣場  32  15   信義區  20220919140840  25.0360361111
# 0005  0005            興雅國中  32  26   信義區  20220919140827  25.0365638889
# 0006  0006          臺北南山廣場  54  42   信義區  20220919140842      25.034047
#
#                 lng                                    ar      sareaen  \
# 0001  121.567904444                         忠孝東路/松仁路(東南側)  Xinyi Dist.
# 0002      121.55742                     忠孝東路四段/光復南路口(西南側)   Daan Dist.
# 0004     121.562325  市府路/松壽路(西北側)(鄰近台北101/台北世界貿易中心/台北探索館)  Xinyi Dist.
# 0005    121.5686639      松仁路/松仁路95巷(東南側)(鄰近信義商圈/台北信義威秀影城)  Xinyi Dist.
# 0006     121.565973  松智路/松廉路(東北側) (鄰近台北101/信義商圈/台北信義威秀影城)  Xinyi Dist.
#
#                                           snaen  \
# 0001    MRT Taipei City Hall Stataion(Exit 3)-2
# 0002  MRT S.Y.S Memorial Hall Stataion(Exit 2.)
# 0004                             Citizen Square
# 0005                     Xingya Jr. High School
# 0006                             NAN SHAN PLAZA
#
#                                                    aren bemp act
# 0001  The S.W. side of Road Zhongxiao East Road & Ro...   77   1
# 0002                Sec,4. Zhongxiao E.Rd/GuangFu S. Rd   11   1
# 0004      The N.W. side of Road Shifu & Road Song Shou.   17   1
# 0005  The S.E. side of Road Songren & Ln. 95, Songre...    6   1
# 0006   The N.E. side of Road Song Zhi & Road Song Lian.   12   1

# %% [markdown]
# ## Convert csv to json and back

# %% [markdown]
# ### Convert dict-of-dict to list-of-dict
#
# 現在我嘗試要把Dictionary of dictionry的資料整理為List of dictionary的型態。要這麼做並不難，我只需要把所有內層的dictionary取出來，一一`append()`到一個空的List即可。最後，我把這樣的結構用`pd.DataFrame()`轉為一個pandas的Data frame。

# %%
import pandas as pd

all_list = []
for k, v in json_obj["retVal"].items():
    all_list.append(v)
    
## convert a list of dictionries to a data frame
df = pd.DataFrame(all_list)
df.head()
# Out:
#     sno             sna tot sbi sarea            mday            lat  \
# 0  0001    捷運市政府站(3號出口)  88   6   信義區  20220919140825  25.0408578889
# 1  0002  捷運國父紀念館站(2號出口)  16   4   大安區  20220919140833      25.041254
# 2  0004            市民廣場  32  15   信義區  20220919140840  25.0360361111
# 3  0005            興雅國中  32  26   信義區  20220919140827  25.0365638889
# 4  0006          臺北南山廣場  54  42   信義區  20220919140842      25.034047
#
#              lng                                    ar      sareaen  \
# 0  121.567904444                         忠孝東路/松仁路(東南側)  Xinyi Dist.
# 1      121.55742                     忠孝東路四段/光復南路口(西南側)   Daan Dist.
# 2     121.562325  市府路/松壽路(西北側)(鄰近台北101/台北世界貿易中心/台北探索館)  Xinyi Dist.
# 3    121.5686639      松仁路/松仁路95巷(東南側)(鄰近信義商圈/台北信義威秀影城)  Xinyi Dist.
# 4     121.565973  松智路/松廉路(東北側) (鄰近台北101/信義商圈/台北信義威秀影城)  Xinyi Dist.
#
#                                        snaen  \
# 0    MRT Taipei City Hall Stataion(Exit 3)-2
# 1  MRT S.Y.S Memorial Hall Stataion(Exit 2.)
# 2                             Citizen Square
# 3                     Xingya Jr. High School
# 4                             NAN SHAN PLAZA
#
#                                                 aren bemp act
# 0  The S.W. side of Road Zhongxiao East Road & Ro...   77   1
# 1                Sec,4. Zhongxiao E.Rd/GuangFu S. Rd   11   1
# 2      The N.W. side of Road Shifu & Road Song Shou.   17   1
# 3  The S.E. side of Road Songren & Ln. 95, Songre...    6   1
# 4   The N.E. side of Road Song Zhi & Road Song Lian.   12   1

# %% [markdown]
# ### Converting csv to json
#
# 現在我想做的是，假設我有一個檔案是CSV檔，但我希望用手動方式把它改為JSON檔，要怎麼做？做法其實就是先把CSV第一列取出來儲存為Key，然後把這個Key一一和每一列的值給對應起來結合成一個又一個的Dictionary，最後把每列所產生的Dictionary用`append()`加入一個List中，就會是一個List of dictionaries結構的JSON格式。
# * https://stackoverflow.com/questions/17912307/u-ufeff-in-python-string

# %%
all_list = []
with open(fin_path, "r", encoding="utf-8-sig") as f:
    for line in f.read().split("\n"):
        row = line.split(",")
        all_list.append(row)
#         print(len(row))
print(all_list[1][-2])
print(all_list[1])

keys = all_list[0]
# Out:
# "噶瑪蘭廣播電台股份有限公司"
# ['"維他肝"', '"豐怡生化科技股份有限公司/朱O"', '""', '"03 31 2022 12:00AM"', '""', '"廣告內容誇大不實"', '"02 2 2022 12:00AM"', '"廣播電台"', '"噶瑪蘭廣播電台股份有限公司"', '""']

# %%
json_list = []
for row in all_list[1:]:
    temp_dict = dict(zip(keys, row))
    json_list.append(temp_dict)
json_list[:3]
# Out:
# [{'違規產品名稱': '"維他肝"',
#   '違規廠商名稱或負責人': '"豐怡生化科技股份有限公司/朱O"',
#   '處分機關': '""',
#   '處分日期': '"03 31 2022 12:00AM"',
#   '處分法條': '""',
#   '違規情節': '"廣告內容誇大不實"',
#   '刊播日期': '"02 2 2022 12:00AM"',
#   '刊播媒體類別': '"廣播電台"',
#   '刊播媒體': '"噶瑪蘭廣播電台股份有限公司"',
#   '查處情形': '""'},
#  {'違規產品名稱': '"現貨澳洲Swisse ULTIBOOST維他命D片calcium vitamin VITAMIN D400粒 補鈣 骨頭"',
#   '違規廠商名稱或負責人': '"張O雯/張O雯"',
#   '處分機關': '""',
#   '處分日期': '"01 21 2022 12:00AM"',
#   '處分法條': '""',
#   '違規情節': '"廣告違規"',
#   '刊播日期': '"11 30 2021 12:00AM"',
#   '刊播媒體類別': '"網路"',
#   '刊播媒體': '"蝦皮購物"',
#   '查處情形': '"輔導結案"'},
#  {'違規產品名稱': '"✈日本 代購 參天製藥 處方簽點眼液"',
#   '違規廠商名稱或負責人': '"蘇O涵/蘇O涵"',
#   '處分機關': '""',
#   '處分日期': '"01 25 2022 12:00AM"',
#   '處分法條': '""',
#   '違規情節': '"無照藥商"',
#   '刊播日期': '"08 27 2021 12:00AM"',
#   '刊播媒體類別': '"網路"',
#   '刊播媒體': '"蝦皮購物"',
#   '查處情形': '""'}]

# %% [markdown]
# ## Read google sheets

# %%
import pandas as pd
sheet_id = '1DlOAXHmxAbdk3lI9836BpJGe6gu59kI5TyLWxmpavXo'
sheet_name = 'Sheet1'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
df = pd.read_csv(url)

# %%
df
# Out:
#           videoId                                          commentId  \
# 0     5buxnIvGQvI                         UgyLL9xMn-1XN8p-uBB4AaABAg
# 1     lbphhEQdw2g                         Ugwnq_P-74ruNsVyMRd4AaABAg
# 2     vOohmT33VU4                         UgwWqEAEOgbJjUiLTfd4AaABAg
# 3     m2EvquMr0pA                         UgyIpHAV8xCVSZ228Pl4AaABAg
# 4     WY7QoQOIBcM                         UgztuFUMsw5tKAEJU254AaABAg
# ...           ...                                                ...
# 9995  GXSRHMG1Vuk  UgxJbJWyigfzZIWCUWN4AaABAg.95pgBqXHjsv95qB_i2w57B
# 9996  dI3W1iyIQXQ  Ugzt_DVcYw8XHpV58cR4AaABAg.8vQfElDFirs8vQinP8EBWH
# 9997  daCqNDjY1tU                         UgySUh3_cLuug0Dv2Fh4AaABAg
# 9998  0KVSA83-JK8                         UgzLwStsrEAvzdamgJN4AaABAg
# 9999  BcBOvNWfTeE  UgzcSOsRhqmXP5lkeOJ4AaABAg.9BLG-YXh0FS9BMa7jdvJS4
#
#      authorDisplayName                                       textOriginal  \
# 0                 諸葛不亮  不修憲、不改國號，你說支持統一就是叛國？\n我說，你要台獨，你寄生於中華民國，你去中國化，你...
# 1              chi chi                                    世界將習慣沒有中國供應鏈的日子
# 2           kenny chiu  好好笑哦~有錢的大老闆還想扣別人紅帽子，卻忘了自己在大陸的廠區裡，有3萬多位共產黨的黨員幹部...
# 3                 でんのう                       台灣只敢罵大陸，菲律賓都不敢罵，日本就更不敢了——趙少康
# 4                2 try     李克強至少是正常人，鼓勵擺攤解決部分失業，至於那個整天喊中國最牛B的扛麥郎，我今天就不罵他了
# ...                ...                                                ...
# 9995                墨卿  中國的病毒來自ABCDE中的C成員，而只有美國擁有ABCDE中的ABCDE，你自己分析看。無...
# 9996               許富隆    別忘了，中國初期海軍也是朝飛潛快發展。防禦作戰小型船會比大型船存活率高，至少開進漁港就可補給。
# 9997           cai cai  柯民眾黨，創黨的錢中共出啊！不想小英勝選的人，自然會出資幫柯組黨，好對抗蔡。柯這麼聰明，組黨...
# 9998               林榮博    信口開河，8年2千萬，憑甚麼？這數字怎麼算的？又是中國給你的MOU嗎？就會唬爛，真想罵三字經。
# 9999               王壹玖                     中國人可能不懂台灣人為何愛用鈔而不用電子支付吧！因為金流隱私
#
#       likeCount 無關-非涉中\n有關-反中\n有關-中立\n有關-親中  Unnamed: 6  Unnamed: 7  \
# 0           325                      有關-中立0         NaN         NaN
# 1           253                      有關-中立0         NaN         NaN
# 2           229                      有關-中立0         NaN         NaN
# 3           228                      有關-中立0         NaN         NaN
# 4           200                      有關-中立0         NaN         NaN
# ...         ...                         ...         ...         ...
# 9995          2                      無關中國立場         NaN         NaN
# 9996          2                      無關中國立場         NaN         NaN
# 9997          2                      無關中國立場         NaN         NaN
# 9998          2                      無關中國立場         NaN         NaN
# 9999          2                      無關中國立場         NaN         NaN
#
#       Unnamed: 8  Unnamed: 9  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0            NaN         NaN  ...          NaN          NaN          NaN
# 1            NaN         NaN  ...          NaN          NaN          NaN
# 2            NaN         NaN  ...          NaN          NaN          NaN
# 3            NaN         NaN  ...          NaN          NaN          NaN
# 4            NaN         NaN  ...          NaN          NaN          NaN
# ...          ...         ...  ...          ...          ...          ...
# 9995         NaN         NaN  ...          NaN          NaN          NaN
# 9996         NaN         NaN  ...          NaN          NaN          NaN
# 9997         NaN         NaN  ...          NaN          NaN          NaN
# 9998         NaN         NaN  ...          NaN          NaN          NaN
# 9999         NaN         NaN  ...          NaN          NaN          NaN
#
#       Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 9995          NaN          NaN          NaN          NaN          NaN
# 9996          NaN          NaN          NaN          NaN          NaN
# 9997          NaN          NaN          NaN          NaN          NaN
# 9998          NaN          NaN          NaN          NaN          NaN
# 9999          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 22  Unnamed: 23
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 9995          NaN          NaN
# 9996          NaN          NaN
# 9997          NaN          NaN
# 9998          NaN          NaN
# 9999          NaN          NaN
#
# [10000 rows x 24 columns]
