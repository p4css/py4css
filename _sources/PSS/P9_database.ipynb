# %% [markdown]
# # P09 Database
# ---
# https://www.learncodewithmike.com/2021/05/pandas-and-sqlite.html

# %% [markdown]
# ## SQlite

# %% [markdown]
# ### Pandas to SQLite

# %%
import pandas as pd
import sqlite3

# %%
# !wget
